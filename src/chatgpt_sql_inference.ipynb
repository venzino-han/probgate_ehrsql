# %% [markdown]
# <!-- Original Implementation by Gyubok Lee -->
# <!-- Refined by Sunjun Kweon on 2024-01-15. -->
# <!-- Note: This Jupyter notebook is tailored to the unique requirements of the EHRSQL project. It includes specific modifications and additional adjustments to cater to the dataset and experiment objectives. -->
#
# # OpenAI Model (ChatGPT) Sample Code for EHRSQL: Reliable Text-to-SQL Modeling on Electronic Health Records
#
# <p align="left" float="left">
#   <img src="https://github.com/glee4810/ehrsql-2024/raw/master/image/logo.png" height="100" />
# </p>
#
# <!-- ## Task Introduction
# The goal of the task is to **develop a reliable text-to-SQL system on EHR**. Unlike standard text-to-SQL tasks, this system must handle all types of questions, including answerable and unanswerable ones with respect to the EHR database structure. For answerable questions, the system must accurately generate SQL queries. For unanswerable questions, the system must correctly identify them as such, thereby preventing incorrect SQL predictions for infeasible questions. The range of questions includes answerable queries about MIMIC-IV, covering topics such as patient demographics, vital signs, and specific disease survival rates ([EHRSQL](https://github.com/glee4810/EHRSQL)). Additionally, there are specially designed unanswerable questions intended to challenge the system. Successfully completing this task will result in the creation of a reliable question-answering system for EHRs, significantly improving the flexibility and efficiency of clinical knowledge exploration in hospitals. -->
#
# ## Steps of Baseline Code
#
# - [x] Step 0: Prerequisites (OpenAI API)
# - [x] Step 1: Clone the GitHub Repository and Install Dependencies
# - [x] Step 2: Import Global Packages and Define File Paths
# - [x] Step 3: Load Data and Prepare Datasets
# - [x] Step 4: Building a predictive model using chatGPT
# - [x] Step 5: Submission

# %% [markdown]
# ## Step 0 : Prerequisites (OpenAI API key)

# %%
import getpass
from IPython.display import clear_output

clear_output()
# Please enter your API key
new_api_key = '<your openai api key>'
while len(new_api_key) == 0:
    new_api_key = getpass.getpass("Please input your API key: ")
    clear_output()

# %% [markdown]
# When submitting your code for code verification, please be sure to submit your OpenAI API key along with your code, like in the sample_submission_chatgpt_api_key.json.

# %% [markdown]
# ## Step 1: Clone the GitHub Repository and Install Dependencies

# %% [markdown]
# Before you begin, make sure you're in the correct directory. If you need to reset the repository directory, remove the existing directory by uncommenting and executing the following lines:

# %% [markdown]
# Now, clone the repository and install the required Python packages:

# %% [markdown]
# Use the `%load_ext` magic command to automatically reload modules before executing a new line:

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Step 2: Import Global Packages and Define File Paths
#
# After setting up the repository and dependencies, the next step is to import packages that will be used globally throughout this notebook and to define the file paths to our datasets.

# %%
import os
import json
import pandas as pd

# Directory paths for database, results and scoring program
DB_ID = 'mimic_iv'
BASE_DATA_DIR = 'data/mimic_iv'
RESULT_DIR = 'sample_result_submission/'
SCORE_PROGRAM_DIR = 'scoring_program/'

# File paths for the dataset and labels
TABLES_PATH = os.path.join('data', DB_ID, 'tables.json')               # JSON containing database schema
TRAIN_DATA_PATH = os.path.join(BASE_DATA_DIR, 'train', 'data.json')    # JSON file with natural language questions for training data
TRAIN_LABEL_PATH = os.path.join(BASE_DATA_DIR, 'train', 'label.json')  # JSON file with corresponding SQL queries for training data
TRAIN_ANS_PATH = os.path.join(BASE_DATA_DIR, 'train', 'answer.json')   # JSON file with corresponding answers for training data
VALID_DATA_PATH = os.path.join(BASE_DATA_DIR, 'valid', 'data.json')    # JSON file for validation data
DB_PATH = os.path.join('data', DB_ID, f'{DB_ID}.sqlite')               # Database path

TEST_DATA_PATH = os.path.join(BASE_DATA_DIR, 'test', 'data.json')

# %%
# This function loads and processes a database schema from a JSON file.

def load_schema(DATASET_JSON): # (TABLES_PATH)
    schema_df = pd.read_json(DATASET_JSON)
    schema_df = schema_df.drop(['column_names','table_names'], axis=1)
    schema = []
    f_keys = []
    p_keys = []
    for index, row in schema_df.iterrows():
        tables = row['table_names_original']
        col_names = row['column_names_original']
        col_types = row['column_types']
        foreign_keys = row['foreign_keys']
        primary_keys = row['primary_keys']
        for col, col_type in zip(col_names, col_types):
            index, col_name = col
            if index > -1:
                schema.append([row['db_id'], tables[index], col_name, col_type])
                
        for primary_key in primary_keys:
            index, column = col_names[primary_key]
            p_keys.append([row['db_id'], tables[index], column])
            
        for foreign_key in foreign_keys:
            first, second = foreign_key
            first_index, first_column = col_names[first]
            second_index, second_column = col_names[second]
            f_keys.append([row['db_id'], tables[first_index], tables[second_index], first_column, second_column])
    db_schema = pd.DataFrame(schema, columns=['Database name', 'Table Name', 'Field Name', 'Type'])
    primary_key = pd.DataFrame(p_keys, columns=['Database name', 'Table Name', 'Primary Key'])
    foreign_key = pd.DataFrame(f_keys,
                        columns=['Database name', 'First Table Name', 'Second Table Name', 'First Table Foreign Key',
                                 'Second Table Foreign Key'])
    return db_schema, primary_key, foreign_key

# Generates a string representation of foreign key relationships in a MySQL-like format for a specific database.
def find_foreign_keys_MYSQL_like(foreign, db_id):
    df = foreign[foreign['Database name'] == db_id]
    output = "["
    for index, row in df.iterrows():
        output += row['First Table Name'] + '.' + row['First Table Foreign Key'] + " = " + row['Second Table Name'] + '.' + row['Second Table Foreign Key'] + ', '
    output = output[:-2] + "]"
    if len(output)==1:
        output = '[]'
    return output

# Creates a string representation of the fields (columns) in each table of a specific database, formatted in a MySQL-like syntax.
def find_fields_MYSQL_like(db_schema, db_id):
    df = db_schema[db_schema['Database name'] == db_id]
    df = df.groupby('Table Name')
    output = ""
    for name, group in df:
        output += "Table " +name+ ', columns = ['
        for index, row in group.iterrows():
            output += row["Field Name"]+', '
        output = output[:-2]
        output += "]\n"
    return output

# Generates a comprehensive textual prompt describing the database schema, including tables, columns, and foreign key relationships.
def create_schema_prompt(db_id, db_schema, primary_key, foreign_key, is_lower=True):
    prompt = find_fields_MYSQL_like(db_schema, db_id)
    prompt += "Foreign_keys = " + find_foreign_keys_MYSQL_like(foreign_key, db_id)
    if is_lower:
        prompt = prompt.lower()
    return prompt

# %% [markdown]
# ## Step 3: Load Data and Prepare Datasets
#
# Now that we have our environment and paths set up, the next step is to load the data and prepare it for our model. This involves preprocessing the MIMIC-IV database, reading the data from JSON files, splitting it into training and validation sets, and then initializing our dataset object.

# %%
from utils.data_io import read_json as read_data

db_schema, primary_key, foreign_key = load_schema(TABLES_PATH)

train_data = read_data(TRAIN_DATA_PATH)
train_label = read_data(TRAIN_LABEL_PATH)

valid_data = read_data(VALID_DATA_PATH)

table_prompt = create_schema_prompt(DB_ID, db_schema, primary_key, foreign_key)

#test
test_data = read_data(TEST_DATA_PATH)
print(table_prompt)
# Out:
# table admissions, columns = [row_id, subject_id, hadm_id, admittime, dischtime, admission_type, admission_location, discharge_location, insurance, language, marital_status, age]
# table chartevents, columns = [row_id, subject_id, hadm_id, stay_id, itemid, charttime, valuenum, valueuom]
# table cost, columns = [row_id, subject_id, hadm_id, event_type, event_id, chargetime, cost]
# table d_icd_diagnoses, columns = [row_id, icd_code, long_title]
# table d_icd_procedures, columns = [row_id, icd_code, long_title]
# table d_items, columns = [row_id, itemid, label, abbreviation, linksto]
# table d_labitems, columns = [row_id, itemid, label]
# table diagnoses_icd, columns = [row_id, subject_id, hadm_id, icd_code, charttime]
# table icustays, columns = [row_id, subject_id, hadm_id, stay_id, first_careunit, last_careunit, intime, outtime]
# table inputevents, columns = [row_id, subject_id, hadm_id, stay_id, starttime, itemid, amount]
# table labevents, columns = [row_id, subject_id, hadm_id, itemid, charttime, valuenum, valueuom]
# table microbiologyevents, columns = [row_id, subject_id, hadm_id, charttime, spec_type_desc, test_name, org_name]
# table outputevents, columns = [row_id, subject_id, hadm_id, stay_id, charttime, itemid, value]
# table patients, columns = [row_id, subject_id, gender, dob, dod]
# table prescriptions, columns = [row_id, subject_id, hadm_id, starttime, stoptime, drug, dose_val_rx, dose_unit_rx, route]
# table procedures_icd, columns = [row_id, subject_id, hadm_id, icd_code, charttime]
# table transfers, columns = [row_id, subject_id, hadm_id, transfer_id, eventtype, careunit, intime, outtime]
# foreign_keys = [admissions.subject_id = patients.subject_id, diagnoses_icd.hadm_id = admissions.hadm_id, diagnoses_icd.icd_code = d_icd_diagnoses.icd_code, procedures_icd.hadm_id = admissions.hadm_id, procedures_icd.icd_code = d_icd_procedures.icd_code, labevents.hadm_id = admissions.hadm_id, labevents.itemid = d_labitems.itemid, prescriptions.hadm_id = admissions.hadm_id, cost.hadm_id = admissions.hadm_id, cost.event_id = diagnoses_icd.row_id, cost.event_id = procedures_icd.row_id, cost.event_id = labevents.row_id, cost.event_id = prescriptions.row_id, chartevents.hadm_id = admissions.hadm_id, chartevents.stay_id = icustays.stay_id, chartevents.itemid = d_items.itemid, inputevents.hadm_id = admissions.hadm_id, inputevents.stay_id = icustays.stay_id, inputevents.itemid = d_items.itemid, outputevents.hadm_id = admissions.hadm_id, outputevents.stay_id = icustays.stay_id, outputevents.itemid = d_items.itemid, microbiologyevents.hadm_id = admissions.hadm_id, icustays.hadm_id = admissions.hadm_id, transfers.hadm_id = admissions.hadm_id]

# %%
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
print(f"Prompt 길이: {len(encoding.encode(table_prompt))}")
#Prompt 길이: 751토큰   << 프롬프트 제한 4000토큰
# Out:
# Prompt 길이: 751

# %% [markdown]
# ### Data Statistics

# %%
print("Train data:", (len(train_data['data']), len(train_label)))
print("Valid data:", len(valid_data['data']))
print("Test data:", len(test_data['data']))
# Out:
# Train data: (5124, 5124)
# Valid data: 1163
# Test data: 1167

# %% [markdown]
# ### Data Format
#
# Before proceeding with the model, it is always a good idea to explore the dataset. This includes checking the keys in the dataset, and viewing the first few entries to understand the structure of the data.

# %%
# Explore keys and data structure
# print(train_data.keys())
# print(train_data['version'])
# print(train_data['data'][0])

# # Explore the label structure
# print(train_label.keys())
# print(train_label[list(train_label.keys())[0]])

# %%
# Prompt for chatGPT containing meta-data of the database such as columns and foreign keys

# %%
from scoring_program.scoring_utils import execute_all
from scoring_program.postprocessing import post_process_sql

pred_dict2 = {'3b9849548e56c59f768d5447': "SELECT MIN(chartevents.valuenum) FROM chartevents WHERE chartevents.stay_id IN ( SELECT icustays.stay_id FROM icustays WHERE icustays.hadm_id IN ( SELECT admissions.hadm_id FROM admissions WHERE admissions.subject_id = 10021118 ) AND icustays.outtime IS NOT NULL ORDER BY icustays.intime ASC LIMIT 1 ) AND chartevents.itemid IN ( SELECT d_items.itemid FROM d_items WHERE d_items.label = 'respiratory rate' AND d_items.linksto = 'chartevents' )"}
pred_dict2 = {id_: post_process_sql(pred_dict2[id_]) for id_ in pred_dict2} # necessary before executing SQL (it replaces placeholders with their actual values)
pred_result2 = execute_all(pred_dict2, DB_PATH, tag='pred') # "execute_all" executes all queries and processes each answer to be "a list of lists".
pred_result2
# Out:
# {'3b9849548e56c59f768d5447': 'error_pred'}

# %% [markdown]
# ## Step 4: Building a predictive model using chatGPT

# %%
# Save your api key into json file
import json

api_path = 'sample_submission_chatgpt_api_key.json'
json_data = {}
json_data['key'] = new_api_key
with open(api_path, 'w') as file:
    json.dump(json_data, file, indent=4)

# %%
#!pip install -U openai

# %%
import os
import re
import json
import tiktoken
from tqdm import tqdm
from openai import OpenAI
import openai

client = OpenAI(api_key=json_data['key'])

def post_process(answer):
    answer = answer.replace('\n', ' ')
    answer = re.sub('[ ]+', ' ', answer)
    return answer

class Model():
    def __init__(self):
        current_real_dir = os.getcwd()
        # current_real_dir = os.path.dirname(os.path.realpath(__file__))
        target_dir = os.path.join(current_real_dir, 'sample_submission_chatgpt_api_key.json')
        if os.path.isfile(target_dir):
            with open(target_dir, 'rb') as f:
                openai.api_key = json.load(f)['key']
        if not os.path.isfile(target_dir) or openai.api_key == "":
            raise Exception("Error: no API key file found.")
        
    #ft:gpt-3.5-turbo-1106:personal::95amfIJ8 # gpt3.5 only sql generate
    #ft:gpt-3.5-turbo-1106:personal::94BvwLbf  # gpt3.5 null+ sql generate
    #ft:gpt-3.5-turbo-0125:personal::96BuBjlL # (상렬님 api) sql generate
    # 파인튜닝한 모델로 지정
    def ask_chatgpt(self, prompt, model="ft:gpt-3.5-turbo-0125:personal::96BuBjlL", temperature=0.0):
        response = client.chat.completions.create(
                    model=model,
                    temperature=temperature,
                    messages=prompt,
                    logprobs=True,
                    top_logprobs=5
                )
        
        return (response.choices[0].message.content, response.choices[0].logprobs.content)
     
    def generate(self, input_data, label_T5):
        labels = {} 
    
        for sample in tqdm(input_data, desc="Processing", unit="query"):
            answer = self.ask_chatgpt(sample['input'])
            labels[sample['id']] = answer
            #processed_answer = post_process(answer)
            #labels[sample_id] = processed_answer

        return labels

# %%
myModel = Model()
#data = valid_data["data"] # why valid?
data = test_data["data"]
data
# Out:
# [{'id': '282f008dd8dfb8f4a1dd6999',
#   'question': 'Tell me the name of the organism that was detected in the last urine test of patient 10027602 on their first hospital visit?'},
#  {'id': '47fd000ef0b1033a8aabfac8',
#   'question': 'Show me the top five most frequently prescribed medications since 2100.'},
#  {'id': '7f07c59357750ac2b84e5221',
#   'question': 'What are the five frequently taken specimens for patients that received extirpation of matter from lung lingula, via natural or artificial opening endoscopic previously within 2 months?'},
#  {'id': 'c83990de3e5d2d218c83528a',
#   'question': "When does patient 8016's influenza quarantine end?"},
#  {'id': 'f430a02bd152c617a86cd2c3',
#   'question': 'How much is patient 10038933 needed to pay for the cost of their hospital visit in 2100?'},
#  {'id': '34e18d3b9b2f055f37a2d04d',
#   'question': 'Call a medical supply company to order more icu equipment.'},
#  {'id': 'dfc058cc8e8d30a29c0177b9',
#   'question': 'After being diagnosed with thrombocytopenia, unspecified , how many patients received a diagnosis of chronic airway obstruction, not elsewhere classified during the same hospital visit?'},
#  {'id': '4b10d0fec2f23acab915e3f3',
#   'question': 'Count how many times in the first hospital visit patient 10004457 had coronary arteriography using two catheters.'},
#  {'id': '647bc08d18cac6dbda791c42',
#   'question': 'When was, for the last time in 10/2100, patient 10018845 prescribed a medication via the sc route?'},
#  {'id': '20c3ddd36c65c44890c3f3e5',
#   'question': 'What was the name of the specimen test that patient 10021666 was given for the first time since 03/2100?'},
#  {'id': '5436413908d5e902536630e8',
#   'question': 'What was the name of the specimen test that patient 10018845 was given for the last time in 10/2100?'},
#  {'id': '4ea7d91dc5b0b0f4da0cb1c6',
#   'question': 'Among patients who were diagnosed with anemia, unspecified since 2100, what are the top three most commonly prescribed medications that followed during the same hospital visit for patients in their 60 or above?'},
#  {'id': '4f489c24ce6a5dfb8485d4f0',
#   'question': 'List the hospital names and their locations.'},
#  {'id': '2675abf72b38410bb4eda4ad',
#   'question': 'What proportion of patients with a diagnosis of acetonuria survive over a 6-month period?'},
#  {'id': '3fc7c5e0ee947f0f155f81ae',
#   'question': 'When was patient 10004422 for the first time leaving the hospital since 2100?'},
#  {'id': '647fbc4c18dc9b7300f25187',
#   'question': "Count the number of days since patient 10021487's first diagnosis of other chronic nonalcoholic liver disease on the current hospital encounter."},
#  {'id': '289be48fc696c588e5a69f9c',
#   'question': 'Pull up the IDs of patients who were diagnosed with cataract extraction status.'},
#  {'id': '3aa4a932c5d33d1b18e92ccc',
#   'question': "What's the end date of patient 7112's influenza quarantine?"},
#  {'id': '9e26fb10ef1cbf36ec4e516b',
#   'question': 'List all the advisors of the patients who were younger than 21.'},
#  {'id': 'eeca589fced0d6ee197e6a2b',
#   'question': 'What are the languages spoken by patients who married before age 30?'},
#  {'id': 'c59a0d9f2769a6133e2d4d28',
#   'question': 'What are the names of the advisors of the patients classified as emergency at admission this year?'},
#  {'id': '9dae764fbde5e025b480528a',
#   'question': 'List all the salaries of the patients who got admitted to the tsicu for their first care unit.'},
#  {'id': 'fa7797af0bc8368e7b76a129',
#   'question': "How much do patient 10004733's respiratory rate shifts measured at 2100-12-30 17:00:00 compared to the value measured at 2100-12-30 16:00:00?"},
#  {'id': 'c1ba984738060f77fc1c4445',
#   'question': 'What number of patients were discharged from the hospital during the previous year?'},
#  {'id': '82af78058d47f0bdbcc12766',
#   'question': "I need to know the phone number of patient 14749's guardian."},
#  {'id': '14867be12327cc1d5dd7348f',
#   'question': 'Tell me the address of patient 2536 and why?'},
#  {'id': 'd3f0d98539d2e9134a435816',
#   'question': 'On the current hospital visit, how many hours have passed since the first time patient 10021487 was prescribed midazolam?'},
#  {'id': '61a3d12ba8e762f3b53709cd',
#   'question': 'What were the top five microbiology tests most frequently performed since 2100?'},
#  {'id': '7e1f1fb83d613020a144d84d',
#   'question': 'Which doctor were patient 30228s seen when he or she last visited the urology department?'},
#  {'id': 'e62aab7f7132343b9c06fb6a',
#   'question': 'What is the most common insurance type among patients with an address in dallas?'},
#  {'id': '21d5909e4b60ccf617b739c8',
#   'question': 'Can you list the top four most frequent procedures that patients received in the same month after having right heart cardiac catheterization in 2100?'},
#  {'id': '67269f11d04e63d8d4a6aaf1',
#   'question': 'List the top five most frequent procedures that patients underwent within the same month after being diagnosed with diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled in 2100.'},
#  {'id': '0c5a19d98fb21ee7f7415577',
#   'question': 'What drug was patient 10021118 prescribed with during the same day after receiving bypass coronary artery, one artery from left internal mammary, open approach this month?'},
#  {'id': '2e40656c79819632933f3d54',
#   'question': 'The number of patients who received drainage of right pleural cavity with drainage device, percutaneous approach.'},
#  {'id': '5459fc4c053a74300114b32b',
#   'question': 'Give me the top four most commonly prescribed drugs since 2100.'},
#  {'id': 'f7f4b0b9f1896ea6f3965250',
#   'question': 'Can you tell me the number of patients that were in the psychiatry careunit since 2100?'},
#  {'id': '915a29cc5d0d25f775a9230e',
#   'question': 'How many duloxetine prescription cases were there since 1 year ago?'},
#  {'id': 'f9a4d8f655bc4658ff929dab',
#   'question': 'Can you list the top three most frequent procedures that patients received in the same hospital encounter after having reposition left maxilla with external fixation device, percutaneous approach?'},
#  {'id': '3daae260dfa809a3ad93e5bd',
#   'question': 'Is the value of arterial blood pressure mean of patient 10031757 second measured on the first ICU visit greater than it is first measured on the first ICU visit?'},
#  {'id': 'a7e5f65ddd31811247f49f56',
#   'question': 'What is the residency status of the patient with the longest hospital stay?'},
#  {'id': '95259eb7cea07ea7f2a5cf48',
#   'question': 'Was the o2 saturation pulseoxymetry of patient 10021487 ever greater than 97.0 on 12/12/2100?'},
#  {'id': 'a17ee07e69ba77566438512c',
#   'question': 'Among patients diagnosed with essential and other specified forms of tremor, what were the top four most common lab tests that followed during the same month throughout this year?'},
#  {'id': '104c93f89e19274578bafb8d',
#   'question': 'When in the first hospital encounter did patient 10038999 receive their first drainage of left pleural cavity, percutaneous approach, diagnostic procedure?'},
#  {'id': 'd9b652601ec09231f9991b24', 'question': 'What is vertical profile'},
#  {'id': 'e0e182b93545a2f808a87836',
#   'question': 'What is the average time taken for appointments to be delayed in the obstetrics and gynecology department?'},
#  {'id': '69c8cd3610b365b38e9dc8fb',
#   'question': 'Has patient 10004235 received the endoscopic insertion of stent (tube) into bile duct procedure?'},
#  {'id': '271fe9a047e24d8cef13cf91',
#   'question': 'What are the dates of graduating from college among the widowed patients who got admitted to the hospital last month?'},
#  {'id': '62967c2f2d2b967d2139be99',
#   'question': 'What were some notable times of their early years?'},
#  {'id': '297a1435453b2870054eb81d',
#   'question': 'What is the average time of delay of appointments in the cardiology department?'},
#  {'id': '4a82faf774a9f3614964283f',
#   'question': 'What were the names of the output that patient 10004720 had last since 12/05/2100?'},
#  {'id': 'e4373b254aad4b11af3fda65',
#   'question': 'When did patient 10029291 last have a fecal bag event on 03/06/2100?'},
#  {'id': '729c62dcfd9ac11a32a56161',
#   'question': 'Has patient 10015860 been prescribed a drug since 1 year ago?'},
#  {'id': '53eee4b8cfb226d8418ce3fa',
#   'question': 'What procedure did patient 10007818 receive for the last time in this year?'},
#  {'id': '1b49fcb3998703d3dd37e81e',
#   'question': 'What is the average total cost of the hospital, which includes the procedure named other incision of pleura?'},
#  {'id': 'fd884f642b26768cc1d7cecf',
#   'question': 'Find the length of the last ICU stay for patient 10006053.'},
#  {'id': '8e96be7df6dd4cc4c1e2a3b4',
#   'question': 'How much is the daily minimum weight of patient 10031757 during the last hospital encounter?'},
#  {'id': '85c3e2700b75549e5f889cf1',
#   'question': 'What is the name of the medication that patient 10036156 received two or more times in their last hospital visit?'},
#  {'id': '770cb760820f25921dc8ac4a',
#   'question': 'How much does a thyroxine (t4), free lab test cost?'},
#  {'id': '939af21d46d24ad0b2940264',
#   'question': 'What does the term ct #3 crepitus mean?'},
#  {'id': 'a2eafdd2283b9391264166aa',
#   'question': 'How much does patient 10018423 change in arterial blood pressure systolic last measured on the last ICU visit compared to the first value measured on the last ICU visit?'},
#  {'id': 'bc8d116f59e4fd75687ea181',
#   'question': 'What new medications were introduced for patient 10004733 today compared to the ones yesterday?'},
#  {'id': '1d673cb43fa93e2f43969f21',
#   'question': 'What is the procedure with the earliest consent date?'},
#  {'id': '376ce2f69b8cda44c3960e60',
#   'question': 'What are the three most commonly administered lab tests?'},
#  {'id': 'ed31b107608f8a15bae7aa15',
#   'question': 'How much is a diagnosis of hypovolemia going to cost?'},
#  {'id': '73e1216fd32c02f0a88adb7b',
#   'question': 'How many patients were prescribed the medicine metronidazole (flagyl) within 2 months after a diagnosis of urinary tract infection, site not specified since 1 year ago?'},
#  {'id': 'a0cc19360d682b011b5a7c9e',
#   'question': "What is the total hospital cost for patient 10021118's stay since 2100?"},
#  {'id': 'eb20ba71a6257201e3668689',
#   'question': 'What was the weight of patient 10006580 in the first measurement?'},
#  {'id': '916c297dfa63e76557d57bb8',
#   'question': "Is patient 10025612's heart rate ever greater than 104.0 on 10/03/2100?"},
#  {'id': 'c410ac2d5f173d57d86ff06c', 'question': 'Where did she never go?'},
#  {'id': 'e134d64a96cc7940427b44cf',
#   'question': 'Did patient 10003046 get a pco2 test in their last hospital visit?'},
#  {'id': '6862d30d896fae9a1cf25fa5',
#   'question': 'What is the maximum total cost of a hospital that dispenses the drug named fenofibrate since 2100?'},
#  {'id': '24e8b0de7b09f21ab851e0c7',
#   'question': 'What is the average time for delays in appointments at the oncology department?'},
#  {'id': '8de87b88f6cd77d22fb75b7a',
#   'question': 'How many hours have been since the first time patient 10021487 was diagnosed with traumatic hemothorax without mention of open wound into thorax in the current hospital visit?'},
#  {'id': '633d7843ff15021b4c6b6ac9',
#   'question': 'Tell me the marital status of patient 10012853 in their last hospital encounter.'},
#  {'id': 'b96e8ac58176933b9e0ee2b3',
#   'question': 'What are the five most commonly tested specimens for patients that were diagnosed with unarmed fight or brawl previously within 2 months?'},
#  {'id': 'f6f7ea6d73b8b83013dc2f03',
#   'question': 'For patients who underwent percutaneous abdominal drainage this year, what were the top five most frequent procedures that followed in the same month?'},
#  {'id': '02641abbf2e5bcb72ad7aedc',
#   'question': 'Please list the top five most frequent specimens tested.'},
#  {'id': 'e94fc44f50cb46d93aaa3008',
#   'question': 'Could you show me the top five most common diagnoses since 2100?'},
#  {'id': '86741d2d640a5dbbfa5d1036',
#   'question': 'Can you tell me the last thyroid stimulating hormone value of patient 10010471 in 05/this year?'},
#  {'id': '0bef44d46b407af716e48911',
#   'question': "How much of a difference is there in patient 10018328's respiratory rate measured at 2100-05-15 14:00:00 compared to the value measured at 2100-05-15 13:00:00?"},
#  {'id': '59d98dcbea98f9f9a4f33d08',
#   'question': 'Since 04/09/2100, when did patient 10013049 have the last input?'},
#  {'id': '3813f972b07ceee5031bb452',
#   'question': 'Did patient 10021666 receive a diagnosis during their last hospital encounter?'},
#  {'id': 'aef4b8676c07216d65074512',
#   'question': 'How many days have passed since patient 10018081 was given a osmolality, urine laboratory test for the last time in the current hospital encounter?'},
#  {'id': '89fa29a6a2fb6b1fff321ece',
#   'question': 'How is ferrous sulfate (liquid) delivered?'},
#  {'id': '6938557cc42ba52caf388bef',
#   'question': "Calculate the aggregate sum for patient 10005909's input since 02/12/2100."},
#  {'id': '1876fa0cb08f316f3b279b75', 'question': 'What hotel did he purchase?'},
#  {'id': '7e045377b0d1df894941da65',
#   'question': 'What is the commonly used name of the drug prescribed to patient 10021312 two times?'},
#  {'id': '6c16600578aa6d76931a6d00',
#   'question': 'What are the five commonly taken specimens for patients who received extirpation of matter from left lower lung lobe, via natural or artificial opening endoscopic previously during the same month since 2100?'},
#  {'id': 'a31f58941f5dbcaed03ddbc3',
#   'question': 'What is the average salary of the patients who believe in christianity?'},
#  {'id': '105c5b90ad1c402ff786e8bc',
#   'question': "What's the cost of the drug known as ferrous sulfate (liquid)?"},
#  {'id': 'e2e9e3d582524db3f2e7d55a',
#   'question': 'Tell me the name of the drug that was first prescribed to patient 10005817 during the last hospital visit via nu route?'},
#  {'id': '7b18e66852f4386ce57b39c1',
#   'question': 'Has there been any mrsa screen microbiology test done for patient 10029484 since 09/2100?'},
#  {'id': '04f2923c808564e420f2e7be',
#   'question': 'In 10/this year, when was the last time patient 10037861 was prescribed 5% dextrose and pantoprazole at the same time?'},
#  {'id': '081a0e4a4a580c6c981d354c',
#   'question': 'Which type of care unit has the patient with the highest page count?'},
#  {'id': 'b486ef7ac176fc054cfa98dd',
#   'question': 'When did patient 10023117 for the first time since 2100 get discharged from the hospital?'},
#  {'id': 'eb33e90dbcfbca0c0e049512',
#   'question': 'How many patients underwent reopening of recent thoracotomy site within the same month after the diagnosis with other acute postoperative pain, since 2100?'},
#  {'id': '3b514d758ae102351dec4dde',
#   'question': 'What boats need to have a throw safety ring'},
#  {'id': 'e812406c3bfd789c61094039',
#   'question': 'How many people were discharged from hospital since 1 year ago?'},
#  {'id': 'fdf5fc622de2b8d98e233ad6',
#   'question': 'What was the drug prescribed to patient 10020740 in 05/2100 for the first time?'},
#  {'id': 'c814a79881c8be3a4809fdb9',
#   'question': "Get patient 10018423's monthly minimum weight information in 2100."},
#  {'id': 'bbcb03fc3471db9511c31648',
#   'question': 'What are the total inputs given to patient 10018845 since 03/27/2100?'},
#  {'id': '1cb7346d2299d0467b9fcb27',
#   'question': 'In 03/last year, was the respiratory rate of patient 10020187 ever greater than 12.0?'},
#  {'id': '919f039cb4f4fe92f49e7c86',
#   'question': 'How many current patients belong to the 30s age category?'},
#  {'id': '1a61783738e4d38f7694a450',
#   'question': 'Tell me all the tests taken in the other department by patient 7698.'},
#  {'id': 'dddc1e74733a55f7407289ad',
#   'question': 'Since 1 year ago, what are the top five most frequently ordered laboratory tests for patients within the same month after diagnosed with dyskinesia of esophagus?'},
#  {'id': 'f3b876d4c257e4b4bc897442',
#   'question': "Can you fetch me patient 10016810's yearly maximum albumin 25% input since 07/02/2100?"},
#  {'id': '5da6b605b949e3c4c068537e',
#   'question': 'When did patient 10039831 first receive a mrsa screen microbiological test in 12/2100?'},
#  {'id': 'e0693814cc896b83b3416d2d',
#   'question': 'Is the value of respiratory rate in patient 10016742 from second measurement on the first ICU visit greater than its first measurement on the first ICU visit?'},
#  {'id': 'fbcd4d482ef4b1adc5b26de8', 'question': 'What did they say to him'},
#  {'id': 'ff935574170a15f329581c0e',
#   'question': 'What are the top three commonly treatments for patients who are 40s in 2100?'},
#  {'id': '1c45da439e97eae264e4d7ce', 'question': 'What does warfarin cost?'},
#  {'id': '54b62111b52beeb031b293c2',
#   'question': 'What new medicines were prescribed to patient 10018081 today compared to those yesterday?'},
#  {'id': 'e99de7acd526ced8910358e1',
#   'question': 'Determine the most influential features for discharge location.'},
#  {'id': '503c1a271385c7a9c485a82a',
#   'question': 'Can you tell me the top four most common procedures since 1 year ago?'},
#  {'id': '025c400c41ad7c9b0b92dc06',
#   'question': 'Count the number of times that patient 10007818 took glucerna 1.5 (full) on the first ICU visit.'},
#  {'id': '348003c7aa52c565e172ee81',
#   'question': 'How many hours has it been since the last time patient 10004733 stayed in the careunit neurology in this hospital encounter?'},
#  {'id': '6e19826cc8478fa8a97d1dee',
#   'question': 'When was the first time in 07/this year that patient 10007818 had the minimum of tobramycin?'},
#  {'id': 'f5d1341aa772a131aa8ee445',
#   'question': 'How many patients were diagnosed with personal history of malignant neoplasm of large intestine in 2100?'},
#  {'id': '83c8da4296018b701b0ac44b',
#   'question': 'What was the last care unit that patient 10007928 was at on the last hospital visit?'},
#  {'id': 'd50f340e88f09cf2749021b3',
#   'question': 'What are the three most commonly ordered lab tests for patients diagnosed with hyperkalemia previously during the same hospital encounter, this year?'},
#  {'id': '45419a10d80abe89bf6669c5',
#   'question': 'Motor current (ma) low (r), can you elaborate on what it stands for?'},
#  {'id': '202ecadc0d16d2f85f8ad189',
#   'question': 'Show me the monthly maximum dextrose 5% input of patient 10009035 in their first hospital encounter.'},
#  {'id': '301ae55bf7f25fd564f985aa',
#   'question': 'Give me the top five most commonly prescribed medications within 2 months to the patients aged 40s after they were diagnosed with constipation, unspecified.'},
#  {'id': 'e1f82dce913d0a344d686dcb',
#   'question': 'What was the total mediastinal output in the last ICU visit that patient 10005817 had?'},
#  {'id': '48b62fcb80cf1fee53b8bfb1',
#   'question': 'What was the total volume of input that patient 10018081 received on this ICU visit?'},
#  {'id': '0b01e88a1ff2627ccad33628',
#   'question': 'What is the number of times patient 10014729 visited the hospital in 2100?'},
#  {'id': '75ad421a0a5e3e4d0b60dc18',
#   'question': 'What month of the year is prescribed for the most antihistamines?'},
#  {'id': 'ac0594e7c1c0b61c1072e703',
#   'question': 'What were the top five most common output events since 2100?'},
#  {'id': 'a999623358b249c2ff668390',
#   'question': 'How many current patients are there aged 60 or above?'},
#  {'id': '426ce736177896950ecec77f',
#   'question': 'When was the first time when patient 10038933 received a other diagnostic procedures on lung or bronchus treatment during the first hospital encounter?'},
#  {'id': '3b5047dc23a01179caf1728d',
#   'question': 'Identify the most common organism associated with poor specimen quality in microbiology tests.'},
#  {'id': '82623a9f149ae4a941d737fc',
#   'question': 'Which condition was diagnosed for patient 10006580 on the last on the last hospital visit?'},
#  {'id': '62024a7f34e319d9ef55142b',
#   'question': 'Which primary physician has the patient with the highest hospital admission cost?'},
#  {'id': '7d5fe035bb44c9237b17dfe5',
#   'question': 'Was patient 10031757 prescribed on their first hospital visit heparin flush (10 units/ml), enoxaparin sodium, or vancomycin?'},
#  {'id': '15b35d75bfa2fee08c48a6c6',
#   'question': 'When was the first time since 114 days ago that patient 10011398 had the maximum respiratory rate for?'},
#  {'id': 'df3f8f6e1b9b51fba40fb909',
#   'question': 'What is haloperidol? what is its effect?'},
#  {'id': 'c5d97a3fa6b67acc42a60f3f',
#   'question': "How many days have passed since patient 10039831's last stay in careunit discharge lounge in this hospital visit?"},
#  {'id': '5f0f9e0915ce37a5ce452e00',
#   'question': 'What are the top five requesters of hematology tests this year?'},
#  {'id': '03697a77b237d131d11e6b7c',
#   'question': 'What are some eye drops that are acceptable for those with dry eye?'},
#  {'id': '09e77a973741f315e0526f82',
#   'question': 'Give me the four most common output events since 1 year ago.'},
#  {'id': '00ddca0abfcd2315f0c91ce6',
#   'question': 'What are the three commonly taken specimens for patients who received control of epistaxis by anterior nasal packing previously during the same hospital encounter?'},
#  {'id': '37833afd75b9cf71f8d0ed01',
#   'question': 'What is the most common year among patients who are not dead and are affiliated with def jam records?'},
#  {'id': 'e57e3f80e3cc0a3b1a3c509c',
#   'question': 'How many patients in 2100 underwent radical excision of other lymph nodes within the same hospital visit after reopening of recent thoracotomy site?'},
#  {'id': 'c60ed59c6b7df6bf5fbfa0cf',
#   'question': 'How many hours have passed since the first time patient 10004733 has taken a albumin lab test during this hospital encounter?'},
#  {'id': 'ec89baea1f34f1904eed2a70',
#   'question': 'Among patients who were prescribed with potassium chl 40 meq / 1000 ml ns, what are the top four most frequently prescribed drugs at the same time since 1 year ago?'},
#  {'id': '78e5fca5ff0661c021019cac',
#   'question': 'What medication was patient 10009049 prescribed two times since 05/2100?'},
#  {'id': '48859a4418a3875bf6082407',
#   'question': "What was patient 10005866's first value of bilirubin, total since 03/2100?"},
#  {'id': '3c3a60ef6ea248ad69d36deb',
#   'question': 'When was patient 10008287 prescribed for the last time a medication via the pr route since 08/2100?'},
#  {'id': 'c486d3f623a7c682d0051190',
#   'question': 'Has any procedure been carried out on patient 10010471 in 2100?'},
#  {'id': '9e71c9503ead8f262e901ec1',
#   'question': 'When was patient 10005348 prescribed with docusate sodium and dorzolamide 2%/timolol 0.5% ophth. for the first time at the same time since 08/2100?'},
#  {'id': '5ff41378c47dc43f9ea36aa9',
#   'question': "What's the total amount of packed red blood cells that patient 10008454 received on their first ICU stay?"},
#  {'id': 'f64502ea7695fae28227dfce',
#   'question': 'Did patient 10005817 receive solution on 12/24/last year?'},
#  {'id': '7437f40a03312a89a951bf71',
#   'question': 'For patients who had hemodialysis, what were the most frequent four microbiology tests carried out during the same hospital visit?'},
#  {'id': '9ed380731316b97f5b4cc772',
#   'question': 'After being diagnosed with personal history of noncompliance with medical treatment, presenting hazards to health in 2100, how many patients received a diagnosis of blood in stool within 2 months?'},
#  {'id': '71b23a88bad2ea2f52f12b02',
#   'question': 'Among patients who were prescribed with phenytoin infatab, what are the top five most frequently prescribed drugs at the same time in 2100?'},
#  {'id': '6375d8b399f74f248505155f',
#   'question': 'Count the number of times patient 10021487 in the current hospital encounter underwent the thoracentesis procedure.'},
#  {'id': '59e57b904fb229550751564d',
#   'question': 'What is the average daily number of patients who had embolism and thrombosis of other specified artery in 2100?'},
#  {'id': '76a3b26583f61cc00377b6a2',
#   'question': 'Count the medications that patient 10004720 was prescribed since 04/2100.'},
#  {'id': 'a735a4a7dda21a510947e2e4',
#   'question': 'What is the adresse of patient 97395?'},
#  {'id': '4e04be3ade7631c7f953c6b5',
#   'question': 'Can you provide the list of the four most commonly ordered specimen tests this year?'},
#  {'id': '45384727303e9e1f25c170a6',
#   'question': 'Which primary physician has the highest patient mortality rate?'},
#  {'id': 'ac9de4303d9e69514c759992',
#   'question': 'What was the organism found in the last urine microbiology test for patient 10038081?'},
#  {'id': '0fae80f812674773157d9f2a',
#   'question': 'Can you specify the gender of patient 10022880?'},
#  {'id': '55712c5df13d0dbf402229f5',
#   'question': 'What were the first outputs of patient 10019917 since 01/19/2100?'},
#  {'id': '11ee027a4849b568c91b8cfe',
#   'question': 'Tell me, what were the five most common microbiology tests since 1 year ago?'},
#  {'id': '3f777e85538090faa2446aeb',
#   'question': 'Since 1 year ago, what are the top five most commonly taken specimens for patients in the same hospital encounter after the diagnosis of intestinal infection due to other organism, not elsewhere classified?'},
#  {'id': 'ea540b00c584340b05707e3c',
#   'question': 'Tell me of the tests patient 57050 has taken in the other department.'},
#  {'id': 'bb5e3f49dbcb908901443bf7',
#   'question': 'Did patient 10029291 take any nacl 0.9% on 02/25/this year?'},
#  {'id': '3f83bca7c25ce27ab09a7ef0',
#   'question': 'What is the difference between weights on patient 10003046 last measured on the last hospital visit compared to the value first measured on the last hospital visit?'},
#  {'id': '94d8481d364db4cbd70b366f',
#   'question': 'How much does patient 10005817 weigh based on the first measurement taken since 10/2100?'},
#  {'id': 'f08654b0c2c58546d18b7efb',
#   'question': 'Since 16 months ago, what specimen test did patient 10002428 receive for the last time?'},
#  {'id': '0298d7de83dc23f17441f202',
#   'question': 'Were there any procedures conducted on patient 10006580 during the previous year?'},
#  {'id': '5ed395ac8cfadff8f83f1d45',
#   'question': 'What is the average value of minimum humidity among the patients who were admitted to the icu more than once?'},
#  {'id': '94122ab2640e86cea1d8cefe',
#   'question': 'Retrieve the top four most frequent procedures that patients underwent in the same hospital visit after being diagnosed with noncompliance with renal dialysis.'},
#  {'id': '197be288d5dde700d2440d8a',
#   'question': 'How much weight did patient 10038999 have at their first measurement on the first hospital encounter?'},
#  {'id': '7ed170e256f209788ad3c985',
#   'question': "Has there been any organism found in patient 10008454's last mrsa screen microbiological examination since 03/2100?"},
#  {'id': 'c731547cf5d2fc4a71b9d129',
#   'question': 'How many days ago was the last time patient 10018081 was diagnosed with other and unspecified hyperlipidemia in their current hospital visit?'},
#  {'id': '3a676bfafee66c27173904e8',
#   'question': 'On the first hospital visit, was patient 10005866 admitted to the emergency room?'},
#  {'id': '16023ddab245248aaafeb7c0',
#   'question': 'Give me a list of microbiology events where the specimen quality was poor.'},
#  {'id': '7dad28b95137a6421d3e7e5e',
#   'question': 'List the most frequent diagnoses for elderly patients with a female next of kin.'},
#  {'id': '411239af52a2ceaa4e79d867',
#   'question': 'How many prescription drugs were ordered for patient 10020944 since 24 months ago?'},
#  {'id': '8f037d1cedf499b333e3a25d',
#   'question': 'When was the first microbiological test of patient 10015931 performed during this month?'},
#  {'id': 'b335cc2faa2de8ffbaba2e95',
#   'question': 'Can you tell me what the drug can be prescribed for patients with esoph varice oth dis nos?'},
#  {'id': '91c770552e4894cdd9ea0079',
#   'question': 'How many patients were tested this year for staph aureus swab?'},
#  {'id': '356df71d59db66ac2534a5d3',
#   'question': 'Can you tell me the total number of patients who were admitted to the hospital since 1 year ago?'},
#  {'id': '264e8e9083e7fe02916af314',
#   'question': 'What was the name of the medication that patient 10025612 was prescribed for the last time in 10/this year?'},
#  {'id': '2178992e7accd7fb74726c82',
#   'question': 'How many patients with permanent residency status were admitted today?'},
#  {'id': '8b765650926782471632323b',
#   'question': 'Which religion has the patient who graduated from college most recently?'},
#  {'id': '52015439c33be0dc487387d4',
#   'question': 'What does a bilirubin, total, ascites lab test typically cost?'},
#  {'id': 'a75bc1cf0cdc6921d07386f9',
#   'question': 'What is the average total cost for a hospital that includes a drug called heparin flush (100 units/ml)?'},
#  {'id': '057355cc0961a85bb8801e26',
#   'question': 'What is the most common location among hospitals?'},
#  {'id': 'c189cadcf09e3eb65ff5c31a',
#   'question': 'What are the three commonly ordered medications for patients aged 60 or above?'},
#  {'id': '6b48b47dea05709d8dddd909',
#   'question': 'Was the calculated total co2 level of patient 10038933 last measured on the first hospital visit less than the second to last measurement on the first hospital visit?'},
#  {'id': '3c71f198ffca8a3ba108d583',
#   'question': "What was the organism found in patient 10027602's first mini-bal microbiology test?"},
#  {'id': 'fdc29ef4f59ae676ae12361e',
#   'question': 'List all the intimes of the icu with page counts lower than 20.'},
#  {'id': 'c7d2ebb491c0d6f0d71149a2',
#   'question': "Can you calculate the duration of patient 10031757's first stay in the intensive care unit?"},
#  {'id': '21c6f900462d7a78f5c1ea2f',
#   'question': 'List the medications prescribed to patients with a male first child.'},
#  {'id': 'e256c7b08d9dde3880221886',
#   'question': 'List the top three most frequent diagnoses that were given to patients within the same month after they were diagnosed with other dependence on machines, supplemental oxygen.'},
#  {'id': 'c8da13e1438ff1e420bfe724',
#   'question': 'Which month of the year antihistamines are most prescribed?'},
#  {'id': '8d2a0e07f81d0db3efed2350', 'question': 'What was los angeles about?'},
#  {'id': 'dbe56779e1a5f940e7fde7f8',
#   'question': 'Keep count of how many times patient 10020944 outputted oral gastric on 03/12/this year.'},
#  {'id': '552b047a4b16894db1150381',
#   'question': 'When did patient 10039708 receive his last microbiology test during the last hospital visit?'},
#  {'id': 'd3311753568bf337795ce830',
#   'question': 'List the medication administrations by hwid1020 to patients.'},
#  {'id': 'd204e30ef557cf80cbde97fe',
#   'question': 'List the top five most frequent procedures performed during this year.'},
#  {'id': '97bd7321746aeee64c00043b',
#   'question': 'How much does patient 10014729 change in mch last measured on the last hospital visit compared to the second to last value measured on the last hospital visit?'},
#  {'id': '06b4d2263fcb4017df542024',
#   'question': 'Tell me the top three diagnoses with the highest 6-month mortality rate.'},
#  {'id': '6d6de28426d8f52bb24d2a0e',
#   'question': 'Was the arterial blood pressure mean of patient 10014729 ever less than 79.0 on 03/07/this year?'},
#  {'id': '2294e45331b6e84efb7132a1',
#   'question': 'Can you list the top three diagnoses that have the highest mortality rate in a 6-month period?'},
#  {'id': 'dbf9297a4c1d683faa792fef',
#   'question': 'What is the yearly minimum volume of emesis that patient 10001217 had since 07/2100?'},
#  {'id': '175e95be4a9b9de2532f300e',
#   'question': 'Show me the top three most common diagnoses of patients with age in their 20s.'},
#  {'id': '962925819932170535210aa7',
#   'question': 'Create a budget plan for the upcoming fiscal year.'},
#  {'id': '15b4990f761db52edf38273c',
#   'question': 'How many days have passed since the last time that patient 10021487 had received a hemoglobin lab test during the current hospital visit?'},
#  {'id': 'c6589161f8c0a3f323c8abde',
#   'question': 'When did patient 10002495 have an input, the last time on the first ICU stay?'},
#  {'id': '70516111809660e05336d719',
#   'question': 'When was the first sputum microbiology test performed on patient 10021487 in 12/2100?'},
#  {'id': 'e19b3138fb3b80c47b5d5688',
#   'question': 'Has patient 10022041 been admitted to an emergency room?'},
#  {'id': '80d095627a05abf538ea0c80',
#   'question': 'What are the three most commonly tested specimens for patients that were diagnosed with secondary diabetes mellitus without mention of complication, not stated as uncontrolled, or unspecified previously in the same month, since 1 year ago?'},
#  {'id': 'a07e014b5e2eb6177b5978a3',
#   'question': 'Since 15 months ago, what was the last weight for patient 10011398?'},
#  {'id': 'bd54a046a04a62d9d40ba4d4',
#   'question': 'This year, what were the four most frequently ordered specimen tests?'},
#  {'id': '2f0d855d95535316ee099fde',
#   'question': "Could you retrieve patient 10018081's daily minimum weight?"},
#  {'id': 'dc671c0fb18f291e1d417779',
#   'question': "What was patient 10004235's last output time of foley on 03/19/2100?"},
#  {'id': '2a440dee395beb895cb930f1',
#   'question': 'What is the three most frequently given microbiology tests since 1 year ago for patients who were previously diagnosed with cervical spondylosis without myelopathy within the same hospital visit?'},
#  {'id': '983188873aa838d898712036',
#   'question': 'Throughout this year, what are the top five most common drugs prescribed during the same hospital encounter to f patients aged 50s after being diagnosed with epilepsy, unspecified, not intractable, without status epilepticus?'},
#  {'id': '0c4dd3081cb0d0d1bacad045',
#   'question': "What was the total hospital cost for patient 10025612's stay on their last hospital visit?"},
#  {'id': 'f8f130b968edc76e907f31af',
#   'question': 'Find the shortest path to the pharmacy from the surgery wing.'},
#  {'id': 'fb2fc2ad15a779e94e21d070',
#   'question': 'How much time in days has passed since the last time patient 10021487 was prescribed vancomycin on this hospital encounter?'},
#  {'id': '82d84ee3f00fa576d3b70969',
#   'question': 'Is the anion gap level of patient 10003400 measured at 2100-06-15 05:34:00 less than the level measured at 2100-06-14 06:15:00?'},
#  {'id': 'b1b111763ce05423f194b8d8',
#   'question': 'What is the minimum total cost of a hospital that runs total protein, urine laboratory tests since 1 year ago?'},
#  {'id': 'ffbb740b9da08e9805048c7f',
#   'question': "What was patient 10014729's insurance plan on the last hospital encounter?"},
#  {'id': '0eba370644940aed20760324',
#   'question': 'What was the name of the drug that patient 10006580 was first prescribed via a sc route in their first hospital visit?'},
#  {'id': 'c1a2df83f43de889081a87be',
#   'question': 'Find the number of patients who had a right heart cardiac catheterization procedure in the last year.'},
#  {'id': 'e5e99a0d4249da9d001cf97b',
#   'question': 'Has any laboratory test been performed on patient 10009049 since 04/2100?'},
#  {'id': '242efda8b736ee27f068d237',
#   'question': 'At what age did patient 8245 get married?'},
#  {'id': '74968f3f69d0e352733f0a96',
#   'question': "When was patient 10027602's first maximum pt in 12/this year?"},
#  {'id': '7e06fac998444826d31f711c',
#   'question': 'In 2100, what is the top three most frequent diagnoses that patients had within 2 months after receiving anastomosis of hepatic duct to gastrointestinal tract?'},
#  {'id': '809a2e5b92679e748ad8312c',
#   'question': 'What was the maximum monthly number of patients diagnosed with surgical operation with implant of artificial internal device as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure in 2100?'},
#  {'id': '3c063dda3762046fb6f125fe',
#   'question': 'Get me the top four most frequently tested specimens that patients took in the same month after being diagnosed with pleural effusion in other conditions classified elsewhere.'},
#  {'id': 'a3585e47c9d9845ccde194bf',
#   'question': 'Has patient 10037975 been given a creatinine, urine test since 15 months ago?'},
#  {'id': '1e939d14d1e8cb2be9b12f9f',
#   'question': 'Count the number of patients diagnosed with dissection of aorta, abdominal who did not come to the hospital within 2 months in 2100.'},
#  {'id': '1254335c726bad61fe05f86b',
#   'question': 'What was the name of the drug patient 10021118 was prescribed for within 2 days after having undergone a bypass coronary artery, two arteries from coronary artery, open approach procedure since 03/2100?'},
#  {'id': '3dcbbb6159d03af90b56b98f',
#   'question': 'What are the top five most frequent medications prescribed within 2 months to the patients in their 50s after they were diagnosed with cerebral artery occlusion, unspecified with cerebral infarction this year?'},
#  {'id': '0ee20c63c4be119281d02113',
#   'question': 'Count the number of patients who were tested throughout this year for vitamin b12.'},
#  {'id': '2340588e1e30b4204874ee2d',
#   'question': 'What were the three most frequently taken lab tests this year?'},
#  {'id': 'df207c83b6a4bbaeca1edcf9',
#   'question': 'What were the top five most common diagnoses that followed within the same month to patients who had received extracorporeal circulation auxiliary to open heart surgery in 2100?'},
#  {'id': 'ccc9522cb728dde5be909759',
#   'question': 'Organize a schedule for routine health check-ups of hospital staff.'},
#  {'id': '914fad11dac859e69fd39132',
#   'question': 'What is the length of the first hospital stay for patient 10016742?'},
#  {'id': 'df9f9f77da1cf00ef44d4e96',
#   'question': 'Has patient 10015931 visited the hospital for admission during this year?'},
#  {'id': '6c5c8aeb2476c9646d1a2c84',
#   'question': 'How many hours have gone by since the last time patient 10004733 was diagnosed with hyperosmolality and/or hypernatremia in this hospital visit?'},
#  {'id': 'fc8557d25a51b1ae5a699bdb',
#   'question': 'Since 07/2100, when was the last time that patient 10031757 was prescribed both lactated ringers and metronidazole (flagyl) at the same time?'},
#  {'id': '4779807de491caeb560e846d',
#   'question': 'Can you tell me the top five most common microbiology tests that occurred in 2100?'},
#  {'id': '7e7f2de29fe0d6cf726ecfd4',
#   'question': 'Did patient 10020306 visit the hospital for admission during the last year?'},
#  {'id': '5d95e49bfd6d7191297dda3e',
#   'question': 'How many patients with ventricular tachycardia were there?'},
#  {'id': 'd9004896ea0a826f5c2e84d4',
#   'question': "Apply a non-linear regression model to predict the progression of patient health status using 'chartevents'."},
#  {'id': '5c5d37eab2cf65bcaafade09',
#   'question': 'Count the number of times that patient 10010471 received the performance of urinary filtration, multiple procedure in the previous year.'},
#  {'id': 'fca670cf3abe9563c60d2488',
#   'question': 'What was the first time patient 10031757 was prescribed milk of magnesia and polyethylene glycol since 08/2100, at the same time?'},
#  {'id': 'c3546915506c74cfcbd2b9ce',
#   'question': 'Show me the top five most frequently prescribed medications since 1 year ago.'},
#  {'id': '8e5f98ce592831b1bc2c6e99',
#   'question': 'What are the total costs incurred on a specific billing date?'},
#  {'id': '499ce7704b771e8824db29e3',
#   'question': 'Provide the sum of inputs for patient 10024043.'},
#  {'id': '290c69f642635c781b5c7611',
#   'question': 'For patients who were given other endovascular procedures on other vessels in 2100, what are the top four most frequent procedures that followed within 2 months?'},
#  {'id': '0dec474abd85aab4b9b4bf61',
#   'question': 'What diagnosis did patient 10003400 receive the last time since 2100?'},
#  {'id': '5151786df7cffa379b3d7bce',
#   'question': 'How many admissions had a last contact time on a weekend and were discharged to home?'},
#  {'id': '9b79fc00bb70e04132ba060c',
#   'question': 'What is the number of times that patient 10018081 had ostomy (output) since 12/03/2100?'},
#  {'id': '234a24d7c0ae3805bd918372',
#   'question': 'What condition was patient 10008454 diagnosed with the last time on the first hospital visit?'},
#  {'id': 'ad86e956c47eb6c95b39bef4',
#   'question': "What is patient 92063's guardian's phone number?"},
#  {'id': '6236365bb1b1dab256878dbe',
#   'question': 'Has patient 10020187 been prescribed any medications?'},
#  {'id': 'e57140ff3a3e15a2db33f62d',
#   'question': "How much of a difference is there in patient 10006580's white blood cells second measured on the first hospital visit compared to the first value measured on the first hospital visit?"},
#  {'id': '3f6d41cb1f9502aad7ee6a0c',
#   'question': 'What are the invoice numbers for patients with no religion?'},
#  {'id': '4724c2961dfc05d2b08ea4be',
#   'question': 'Did patient 10020187 receive restriction of intracranial artery with intraluminal device, percutaneous approach in the last hospital encounter?'},
#  {'id': '0cd4abf8740b632d0571fe59',
#   'question': 'Is arterial blood pressure systolic of patient 10027602 last measured on the last ICU visit greater than the first value measured on the last ICU visit?'},
#  {'id': '8a56f098370ca6af99a28b53',
#   'question': 'What was the last prescribed dose of simvastatin that patient 10015860 got in the first hospital visit?'},
#  {'id': '1146fa67574092d95567b1a4',
#   'question': 'How many primary physicians have been at the hospital since this year?'},
#  {'id': '05a1330cdcd6729af414b7c7',
#   'question': 'What is the 6-month survival probability for patients living with a other and unspecified angina pectoris diagnosis?'},
#  {'id': '87fcf9c0339594cc79adb945',
#   'question': 'Can you count the instances of the introduction of other thrombolytic into central vein, percutaneous approach procedure in 2100?'},
#  {'id': '7930f61ad162e76931f9a609',
#   'question': 'What is the average age of patients admitted this year with non-resident status?'},
#  {'id': 'b0bf656133ed5d5d8d5fd764',
#   'question': "When was the first time on the first ICU stay that patient 10027602's o2 saturation pulseoxymetry was greater than 95.0?"},
#  {'id': '44ba2f356939ab27e43cbc9a',
#   'question': 'When was patient 10000032 first given a creatinine test in 05/2100?'},
#  {'id': '76975e0fd7750cb9f40f9724',
#   'question': 'How many patients received omeprazole within 2 months after the confirmation of personal history of tobacco use in 2100?'},
#  {'id': '38ee8e2e9b40d24650f7091e',
#   'question': 'What are the record companies of the male patients?'},
#  {'id': '5cf885d109f3f215844f994e',
#   'question': "How many hours have passed since patient 10004733's last stay in careunit medical/surgical intensive care unit (micu/sicu) in this hospital encounter?"},
#  {'id': '9ab8b4d1a143e09289a29059',
#   'question': 'What is the maximum metamyelocytes of patient 10038992?'},
#  {'id': '6921a2f2bc13f22b2242fbf5',
#   'question': "What's the number of patients who were diagnosed with bite of other animal except arthropod since 2100?"},
#  {'id': 'c82af717a41e0911aa58968c',
#   'question': 'What are the record companies that muslim patients are affiliated with?'},
#  {'id': '7a1d975dc39f51887f287327',
#   'question': 'Is patient 10020944 recorded as male or female?'},
#  {'id': '5db93544ca13afa9605c5f92',
#   'question': 'How many current patients are 30s?'},
#  {'id': '20aebcd9d340bf34f6432bce',
#   'question': 'Call a medical laboratory to expedite test results.'},
#  {'id': '964217a388912122a2c89866',
#   'question': "Tell me patient 10020944's average calcium, total value in 03/2100?"},
#  {'id': 'e27e5f5f51fb07c86c07786c',
#   'question': 'Tell me the top five most common diagnoses of patients aged 20s in 2100.'},
#  {'id': '4fd0b93be92c900c3081f4b3',
#   'question': "How much of a difference is there in patient 10035185's arterial blood pressure mean last measured on the first ICU visit compared to the second to last value measured on the first ICU visit?"},
#  {'id': 'd4949e694ea61ec816d403c4',
#   'question': 'On 04/05/this year, what was the average value of respiratory rate for patient 10012552?'},
#  {'id': '37d260bf174746e3b0f83bb0',
#   'question': 'What are the five most commonly prescribed drugs for patients diagnosed with postprocedural fever previously within the same hospital visit, in 2100?'},
#  {'id': 'ced205244613e91e3ff9ec97',
#   'question': 'Count the number of times patient 10021487 received replete with fiber (full) on this month/13.'},
#  {'id': 'd26c89312ff5e7f567fca6f9',
#   'question': 'When does patient 1819 cease to be in a quarantine for influenza?'},
#  {'id': '6d14fafef38d93f2e020c386',
#   'question': 'Count how many times in the first hospital encounter patient 10018328 experienced the restriction of left internal carotid artery with intraluminal device, percutaneous approach procedure.'},
#  {'id': 'd5a64cdf313b92560f9cfb58',
#   'question': 'When did patient 10027445 since 1 year ago for the last time leave the hospital?'},
#  {'id': '879dfc7ea11934d27bc66bc7',
#   'question': 'Can you name the top three diagnoses with the highest 6-month mortality rate?'},
#  {'id': 'aeb4b3e5ce8038a370e1e7c1',
#   'question': 'Count the number of patients who underwent a microbiological mini-bal test since 2100.'},
#  {'id': '571b776d0c624ec21b51af31',
#   'question': 'Has patient 10024043 had any organisms detected in his first mrsa screen microbiology test since 1 year ago?'},
#  {'id': '2b27156e1bc6e928eb6b916e',
#   'question': "Get patient 10039831's yearly minimum weight information since 08/2100."},
#  {'id': 'e59eccf79830c0ce43f8ca5c',
#   'question': 'How much metformin xr (glucophage xr) was prescribed to patient 10016150 first time in 05/this year?'},
#  {'id': 'd69a4b8b51374de9e093dde2',
#   'question': 'How many hours have passed since patient 10004733 stayed in the careunit medicine on this hospital visit for the first time?'},
#  {'id': '065af69d45121445e06b6397',
#   'question': 'What is the full form of ai ncp - problem resolved?'},
#  {'id': 'c47c43f5d2824c6b2c4f54fe',
#   'question': 'List the top five most frequent procedures performed since 2100.'},
#  {'id': 'a318cf44208857796ab33806',
#   'question': 'What is the 3-month survival rate for patients diagnosed with other psoriasis?'},
#  {'id': '99674b531e81a982dc797973',
#   'question': 'What are the five most common microbiology tests for patients that had previously received introduction of other thrombolytic into peripheral vein, percutaneous approach within the same hospital visit since 2100?'},
#  {'id': '1582b6838cb5976778505bd3',
#   'question': 'When did michael laudrup start playing with fc barcelona?'},
#  {'id': '2cfebbc052bed80d23e156ba',
#   'question': 'What are the 10 most common side effects of clarithromycin??'},
#  {'id': 'bdd039b89d9bf57a1d3c4e49',
#   'question': 'What are the three most common microbiology tests for people who were diagnosed with malignant neoplasm of lower third of esophagus earlier in the same hospital encounter, since 2100?'},
#  {'id': '8bca7f05d41683561e862158',
#   'question': 'Tell me the total number of patients in the psychiatry in this year.'},
#  {'id': '3f3b727d5effabd567b64400',
#   'question': 'Give me the top four most commonly prescribed medications in the same month to the patients aged 50s after they were diagnosed with non-st elevation (nstemi) myocardial infarction throughout this year.'},
#  {'id': 'ae1a61baad9fcbb6ccb57c0b',
#   'question': 'Give me the top four most frequent diagnoses that patients were diagnosed with in the same month after being diagnosed with body mass index 35.0-35.9, adult this year.'},
#  {'id': '62ccc1a233fe17718b439b9c',
#   'question': 'What can be prescribed for the hyposmolality patient?'},
#  {'id': 'ca02915764bab9c149d0c83e',
#   'question': 'What are the four most commonly taken specimens that patients were tested in the same hospital encounter after receiving a respiratory ventilation, 24-96 consecutive hours procedure since 2100?'},
#  {'id': '160050686bf62ecef4c7dce6',
#   'question': 'Could you tell me the name of the drug that was prescribed two or more times in 07/this year to patient 10020740?'},
#  {'id': '5886a94103455554061fb16a',
#   'question': 'What was the quantity of glucose gel dose prescribed to patient 10020740 in 07/this year?'},
#  {'id': '0d61464fe9f411c1b299ffef',
#   'question': 'Count the number of times that patient 10009035 in 12/last year had a or urine output.'},
#  {'id': '12dc2c314dc8f5fd30f51823',
# ...
#   'question': 'Calculate the patients who received a serology/blood microbiology test since 2100.'},
#  {'id': 'e06b5c902a757922a7a2e945',
#   'question': 'Count the number of patients diagnosed with gastro-esophageal reflux disease without esophagitis who did not come to the hospital within 2 months since 2100.'},
#  {'id': 'fbf3603d3d2d818a10d4d5b4',
#   'question': 'Among patients who were diagnosed with acute alcoholic intoxication in alcoholism, continuous during this year, what are the top five most commonly prescribed medications that followed in the same hospital encounter for patients in their 50s?'},
#  {'id': '16b479cf35ef4b2c6a5488a1',
#   'question': 'What is the total amount of kcl (bolus) input that patient 10020187 got since 02/02/2100?'},
#  {'id': 'b6e85f562fb3d32bcc7d415f',
#   'question': "Since 02/2100, what was patient 10021487's first microbiology test time?"},
#  {'id': '740f87417b7715602b678286',
#   'question': 'Did patient 10029484 have any tests for creatine kinase, mb isoenzyme during the previous month?'},
#  {'id': 'd6ab8927156136206a55d8a8',
#   'question': 'During the current hospital visit, has patient 10021487 been prescribed with readi-cat 2 (barium sulfate 2% suspension), plasmalyte, or acetazolamide sodium?'},
#  {'id': '2a853454c790cac539c5c85d',
#   'question': 'On 11/16/2100, did patient 10006053 have any cryoprecipitate input?'},
#  {'id': 'ad25b33f618fbda4463dc6d1',
#   'question': 'Is patient 10021938 recorded as male or female?'},
#  {'id': '9b70f7f7a60a0c7994cc0ea0',
#   'question': 'List the top five most common diagnoses for patients in their 20s throughout this year.'},
#  {'id': '9a35c7b42b40e00811be3aac',
#   'question': 'Has patient 10039997 received nacl 0.9% in 12/last year?'},
#  {'id': 'cfce5f7c561e0bbfd11e26e0',
#   'question': 'How much does drainage of pericardial cavity with drainage device, percutaneous approach cost?'},
#  {'id': '7294971600b3da69c5f504bd',
#   'question': 'Can you tell me the name of the procedure that patient 10004720 received first?'},
#  {'id': '811d7b1ce1d2dbdbb4648a1b',
#   'question': 'What procedure was performed on patient 10021938 two times since 11 months ago?'},
#  {'id': '02e5f85b19066ccbf99fdcc0',
#   'question': 'What condition was patient 10015860 diagnosed with the last time?'},
#  {'id': '7873d7d50e05f38127c1a555',
#   'question': 'Has patient 10005866 had any type of diagnosis in this year?'},
#  {'id': 'b0433b76493ed986baca0a4d',
#   'question': 'What is the average number of standing tackles made by patients younger than 40?'},
#  {'id': '137af49a158f5739eb59024e',
#   'question': 'What is the 3-month survival probability for patients living with a asymptomatic human immunodeficiency virus [hiv] infection status diagnosis?'},
#  {'id': '88a650d28643d60da24b7b3f',
#   'question': 'What was the last recorded height for patient 10006580 during the first hospital encounter?'},
#  {'id': 'b41f33bd6784e344776668f2',
#   'question': 'What was the first dose of 0.9% sodium chloride (mini bag plus) given to patient 10015931?'},
#  {'id': 'ad51af24b14e2258cfa50fab',
#   'question': 'Find any images used for educating patients about their condition or treatment.'},
#  {'id': 'ec24c1254363c0ed83ac0fa9',
#   'question': 'How much does the cost of a other and unspecified escherichia coli [e. coli] diagnosis cost?'},
#  {'id': '20652261cb0352fb90678734',
#   'question': 'What is the yearly average dose of po intake that patient 10001725 took since 04/03/2100?'},
#  {'id': '16df9ac99e3822d7b993b443',
#   'question': 'During this year, what are the top five most frequent lab tests given to patients during the same hospital encounter after pleurisy without mention of effusion or current tuberculosis?'},
#  {'id': 'cd9067d6c88100bac2cc82c3',
#   'question': 'What are the three most commonly tested specimens since 1 year ago?'},
#  {'id': '70d14dce56962dcc9931c667',
#   'question': 'What are the methods for ingesting phenytoin sodium?'},
#  {'id': '5a8100c52ed7e15c554fa177',
#   'question': 'What side effects does propofol have on the body?'},
#  {'id': 'e20f1e8b13cc94e7c1a8e027',
#   'question': "What does the average mcdonald's worker make per hour"},
#  {'id': 'c8a2241d70df2c163edad761',
#   'question': "What was patient 10039997's last value of the heart rate since 08/13/2100?"},
#  {'id': '42dafd4cb9bdc6f884302fb7',
#   'question': 'Calculate how many times patient 10021487 had the input of kcl (bolus) in 12/last year.'},
#  {'id': 'fa829a69da2e049d895218f5',
#   'question': 'What is the number of times that patient 10020786 had pre-admission on 12/04/last year?'},
#  {'id': 'c4b26c0ae57a5f77fcd0c46d',
#   'question': 'Has patient 10022281 been prescribed a drug since 24 months ago?'},
#  {'id': '7fdd9cf1dba27d7f0f1ae05c',
#   'question': 'What is the most common drug color prescribed to patients with diabetes?'},
#  {'id': '7eeda0d4bfae5ffe07de0b9b',
#   'question': 'How many hours has it been since the first time patient 10018081 stayed in the careunit emergency department on the current hospital encounter?'},
#  {'id': '402477d5ceb24dc09d2bc1ee',
#   'question': 'What is the average date of death among patients who were deceased and were affiliated with sony records?'},
#  {'id': '0935d36097c74026c3b0a63f',
#   'question': 'What was the insurance plan of patient 10021666 during the first hospital encounter?'},
#  {'id': '5f37e3810a824edf13d26696',
#   'question': "Count the number of procedures that resulted in a 'successful' outcome this year."},
#  {'id': '3e4b52c69a2bdf36e4f03676',
#   'question': 'Retrieve the marital status of patient 10005866 during their last hospital encounter.'},
#  {'id': 'c5dc45f6c0dd8b3d6e931bad',
#   'question': 'What medication should be prescribed to patients with glaucoma nos?'},
#  {'id': '6b1fe6a4f18cb1365ffa3764',
#   'question': "What are patient 10004720's changes in weight last measured on the first hospital visit compared to the second to last value measured on the first hospital visit?"},
#  {'id': '88823049d5169eac0fe75ddc',
#   'question': 'What is the daily average dose of d5 1/2ns that patient 10039831 took since 12/16/2100?'},
#  {'id': '9fd9c725dd075244d0eab9a8',
#   'question': 'What was the maximum sodium of patient 10020187?'},
#  {'id': '0b0f42b85fbcc6d0f0d14321',
#   'question': 'Do you have an idea when patient 19428 goes into the closed bronchial biopsy procedure?'},
#  {'id': 'e6904c8a3dbd63bea6afef75',
#   'question': "Whose phone number is the phone number of patient 40707's guardian?"},
#  {'id': 'd91a86b3f19888f5557a404a',
#   'question': 'Since 08/2100 has patient 10004733 received a hyaline casts test?'},
#  {'id': '4b635ac1325eaf0dd75988d5',
#   'question': 'In 04/last year, has patient 10001725 been prescribed with pantoprazole, albuterol 0.083% neb soln, or propranolol?'},
#  {'id': '3b4b66ef7b25fe1a09950008',
#   'question': 'Is o2 saturation pulseoxymetry of patient 10031757 second measured on the first ICU visit greater than the first value measured on the first ICU visit?'},
#  {'id': '6968bd319470944ced5ca337',
#   'question': 'What is the cost of a medication named ibuprofen?'},
#  {'id': '37b440fc3a82a50003dce7ed',
#   'question': "What was patient 10019385's last creatine kinase, mb isoenzyme lab test time in their last hospital encounter?"},
#  {'id': '9d986798e601a07346824191',
#   'question': "What's the cost of a treatment known as excision of dental lesion of jaw?"},
#  {'id': '5614cf0da6a6dc8d7f53e2e4',
#   'question': 'In the last ICU stay, what was the average value of heart rate of patient 10019385?'},
#  {'id': '7f45ec7922873c06d1b67747',
#   'question': 'What is the average yearly number of patients who had encounter for palliative care?'},
#  {'id': '71f42d6affc0c51c8579d29f',
#   'question': 'Find out the number of patients who were discharged from the hospital.'},
#  {'id': '4b72e7b13c37b47053d926d9',
#   'question': 'Can you provide the monthly maximum output of pre-admission for patient 10022041?'},
#  {'id': '531ee3368f9eb81ac4413215',
#   'question': "How about what's the address of patient 22983?"},
#  {'id': 'e3d036a9b6ba87b79199b9e2',
#   'question': 'What was the name of the procedure that was performed two or more times since 10 months ago on patient 10020740?'},
#  {'id': 'e6fc873eaca2527956432aa0',
#   'question': 'How many people were admitted to the hospital since 2100?'},
#  {'id': '71491588d7f25a31522660fb',
#   'question': 'What is the length of stay in the icu for the patient having the most standing tackles?'},
#  {'id': 'e75cb39d6c5c866076d93717',
#   'question': 'Count the number of patients diagnosed with cocaine abuse, unspecified.'},
#  {'id': '842de74a9f0719c2f68b9f9f',
#   'question': 'Get me the top five most frequent specimens that patients were tested within 2 months after receiving bypass coronary artery, one artery from aorta with autologous venous tissue, open approach since 2100.'},
#  {'id': 'a12d2706258e7cd94b157f13',
#   'question': 'How many times did patient 10021487 stay in ICU?'},
#  {'id': '03631d36b3026382aa32c6b9',
#   'question': 'Why did nicholas sparks divorce his wife'},
#  {'id': '135380cceeececcc1d31beb3',
#   'question': 'Did patient 10021666 come into an ER on their first hospital encounter?'},
#  {'id': '1bdf02ef77df577cf44deaee',
#   'question': 'Since 2100, how many patients were discharged from the hospital?'},
#  {'id': '69356637e317ad0c9ca83dce',
#   'question': 'How many prescriptions were ordered for acetylcysteine (iv) in 2100?'},
#  {'id': 'd4b6c0167cad9291a4e1dbec',
#   'question': 'Is the value of troponin t in patient 10007058 from the last measurement on the first hospital visit greater than its second to last measurement on the first hospital visit?'},
#  {'id': '672d81cda5b780896726e4f2',
#   'question': "When was patient 10015860's respiratory rate less than 21.0 for the first time since 06/06/2100?"},
#  {'id': 'd39e6cca12842e2e3d53b7cd',
#   'question': "What was the first measurement of patient 10013049's height since 25 months ago?"},
#  {'id': '9a53c5a84a90577e106b30ec',
#   'question': "In the first hospital visit, what was patient 10016150's last procedure time?"},
#  {'id': '732aa8afc5a1fa558876a572',
#   'question': "What is patient 10004235's difference in weight from the last value measured on the first hospital visit compared to the first value measured on the first hospital visit?"},
#  {'id': '826d1ec55b9cb1dcd3714ce0',
#   'question': "What's the minimum total hospital charged for a visit with a white blood cells lab test since 1 year ago?"},
#  {'id': 'c2cedc6cff27f2430e1a1578',
#   'question': 'When was the first time patient 10026354 was diagnosed with dislocation of jaw, initial encounter since 2100?'},
#  {'id': '7ecf2158ebabd494e514c3df',
#   'question': 'What does a procedure called total esophagectomy cost?'},
#  {'id': '9f654e2d9df31f2baea54b3e',
#   'question': 'How many patients stayed at emergency department observation in 2100?'},
#  {'id': '6eddc8f5b659e5efd6afac0c',
#   'question': 'What are the three most frequently ordered medications that f patients aged 60 or above were prescribed within 2 months after they were diagnosed with unspecified essential hypertension in 2100?'},
#  {'id': '2b7276378eab1b3d2a5dbc38',
#   'question': 'How much total input has patient 10014354 received in the last ICU stay?'},
#  {'id': 'ec2f5213e46e1995aa93f723', 'question': 'What was his first attempt?'},
#  {'id': 'cf75e230ba259301517169ac',
#   'question': 'What was the total output for patient 10001217 since 12/02/2100?'},
#  {'id': '73a44b74d4ae03e85322ee51',
#   'question': 'What does fusion or refusion of 2-3 vertebrae cost?'},
#  {'id': '568a32b005438f0d65d4f758',
#   'question': 'When did patient 10020786 receive the last magnesium test in their last hospital encounter?'},
#  {'id': '5061007ac9969cb42e64a034',
#   'question': 'When was the first time patient 10018328 had been prescribed enalapril maleate and amlodipine at the same time since 02/2100?'},
#  {'id': '849c73c34b291683b2d24907',
#   'question': 'Tell me the drug that was prescribed to patient 10021487 for the first time through the iv route since 09/2100?'},
#  {'id': '4ca2e0381437a360c430c3ff',
#   'question': 'What is the location of the hospital that admitted the most patients with diabetes?'},
#  {'id': '266fdb4aab6dfeee91633110',
#   'question': 'What is the rank of the top four most frequent output event since 1 year ago?'},
#  {'id': '3dd7cbf61468460681ff3c30',
#   'question': 'What were the top five most common treatments given to patients in their 60 or above since 2100?'},
#  {'id': 'd7835456c04a228c24df961d',
#   'question': 'What is the number of patients who died after diagnosis of septic shock within 2 months during the last year?'},
#  {'id': 'f98f1fc6388ce3227b7181d9',
#   'question': 'Which antihistamine is the most'},
#  {'id': '403d0f9ebacfc71a842b6d25',
#   'question': 'Who are the patients that most recently received input medication from hwid1010?'},
#  {'id': 'a2de199eb11275f923c798c8',
#   'question': 'Can you tell me the first medicine that was prescribed to patient 10007795?'},
#  {'id': '8e97f8923eae1120693cf379',
#   'question': 'Is the value of mchc of patient 10026255 second measured on the last hospital visit less than it was first measured on the last hospital visit?'},
#  {'id': '6daa9b7fb20a9577136bb303',
#   'question': 'What are the new medications prescribed to patient 10039831 today in comparison to yesterday?'},
#  {'id': '0720463e9ae6087374c45f6a',
#   'question': 'I mean, what kinds of side effects does ns have?'},
#  {'id': '7bb4dd3032dd60767f552577',
#   'question': 'Has patient 10006580 had any medication since 13 months ago?'},
#  {'id': '18df1101ddb265b920569563',
#   'question': 'What are the names of the procedures performed on patient 10020740 two or more times since 14 months ago?'},
#  {'id': '817d23cea9de1a0e459a25c3',
#   'question': 'How much is a bilirubin, indirect lab test?'},
#  {'id': '88c772d92cd993b8ce3eb5a9',
#   'question': 'What was the name of the medication that patient 10004235 was prescribed two or more times?'},
#  {'id': '60e8ab147beb8159de92a539',
#   'question': 'How much is the average total cost of a hospital visit that includes a free calcium lab test in 2100?'},
#  {'id': '5c069998e95156db5e7d2e7e',
#   'question': 'What is the minimum daily number of patients that are suffering from atherosclerotic heart disease of native coronary artery with unstable angina pectoris?'},
#  {'id': '79c09379a9bdcb0e976df35f',
#   'question': 'Show me the top four most common microbiology tests since 1 year ago.'},
#  {'id': '524208cb99d72ea26c67c3f9',
#   'question': 'How many times did patient 10019385 check into the ICU during this year?'},
#  {'id': '66830a78dcd7a98c6df848db',
#   'question': 'Get me the patient IDs who were diagnosed with acute systolic heart failure since 2100.'},
#  {'id': '84564eb53eb9b3302bd9acf8',
#   'question': 'Can you tell me the top four most common microbiology tests that occurred in 2100?'},
#  {'id': '6d1e9f74415d70381cffcd18',
#   'question': 'Has patient 10021938 had a procedure since 2100?'},
#  {'id': '8227bef3ad3149f4b7e3b6e2',
#   'question': 'Count the number of patients who had their extirpation of matter from left main bronchus, via natural or artificial opening endoscopic performed since 1 year ago.'},
#  {'id': '2b5707d23faf1d54bc3688c3',
#   'question': 'On their first hospital visit, what was the age of patient 10022880?'},
#  {'id': '20b82bb795428cdccd820bb5',
#   'question': "Calculate the LOS of patient 10031757's first hospital stay."},
#  {'id': 'ceb130d1950aa38990b64736',
#   'question': 'What is the maximum total cost for a hospital that conducts a albumin, ascites lab test?'},
#  {'id': '666f86f3566bfabb76e587a7',
#   'question': 'When was patient 10038992 last prescribed a drug via the neb route since 07/2100?'},
#  {'id': '7329fbf5056c86af263e9033',
#   'question': 'Could you show me the total void output of patient 10024043?'},
#  {'id': '9096c27221e67c2da2e1c060',
#   'question': 'And when does patient 12927 go into the percu abdominal drainage procedure?'},
#  {'id': '089417994ad72edcca9f8050',
#   'question': 'Count the number of patients who had insertion of intercostal catheter for drainage within 2 months after having been diagnosed with home accidents since 2100.'},
#  ...]

# %%
# sql gen+ null classify
system_msg = "You are 'SQLgpt', a sophisticated AI designed to transform user questions into precise SQL queries. Focus on crafting SQL queries that accurately reflect the intentions of the questions. Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single ' nor double \"). The integrity and accuracy of your responses are paramount. When faced with ambiguity, lack of context, or a query that exceeds the limits of the available data, you must opt for a 'null' response rather than producing a potentially incorrect SQL. Your judgment in these situations is crucial, as we prioritize accuracy and the prevention of misinformation above all."
system_msg = "You are 'SQLgpt', an advanced AI designed to convert user questions into accurate SQL queries. It is crucial to accurately reflect the user's intentions and strictly adhere to the standard SQL format guidelines. The generated SQL queries must adhere to the standard SQL format and should not be enclosed in quotes (neither single ' nor double \"). The integrity and accuracy of responses are paramount. In cases of uncertainty, insufficient context, or when the query exceeds the available data limits, it is essential to respond with 'null' instead of potentially generating inaccurate SQL. Your judgment in such situations is critical, emphasizing the importance of accuracy and error prevention. Responding with 'null' in doubtful cases is highly important"
# + schema
system_msg = "You are 'SQLgpt', an advanced AI designed to convert user questions into accurate SQL queries. Your goal is to generate SQL queries that accurately represent the user's intent while strictly adhering to standard SQL format guidelines. Remember, generated SQL queries must not contain quotes, neither single (' ') nor double (\"). The integrity and accuracy of your responses are critical. In situations of uncertainty, insufficient context, or when a query might exceed the data available, opting for 'null' instead of generating a potentially incorrect SQL is imperative. Your judgment is crucial in preventing errors and ensuring accuracy. Always choose 'null' in doubtful situations to avoid generating inaccurate SQL. Additionally, be aware of the database schema and ensure your SQL queries do not go beyond the schema's scope or generate incorrect SQL based on the schema's limitations."
# system_msg = "You are 'SQLgpt', a sophisticated AI designed to transform user questions into precise SQL queries. Focus on crafting SQL queries that accurately reflect the intentions of the questions, with a special emphasis on utilizing the following table structures and their columns effectively:\n\n" 
# system_msg2 = "Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single ' nor double \"). The integrity and accuracy of your responses are paramount. When faced with ambiguity, lack of context, or a query that exceeds the limits of the available data, you must opt for a 'null' response rather than producing a potentially incorrect SQL. Your judgment in these situations is crucial, as we prioritize accuracy and the prevention of misinformation above all. Make sure to reference the table structures provided to maximize the relevance and accuracy of your SQL queries."
# #only sql generate
system_msg = "You are 'SQLgpt', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single ' nor double \"). Your primary goal is to accurately generate the exact SQL query for each question presented to you."

# %%
input_data = []
for sample in data:
    sample_dict = {}
    sample_dict['id'] = sample['id']
    
    #conversation = [{"role": "system", "content": system_msg + table_prompt+'\n\n'+system_msg2}]
    conversation = [{"role": "system", "content": system_msg +'\n\n'}]

    #conversation = [{"role": "system", "content": system_msg}]
    user_question_wrapper = lambda question: '\n\n' + f"""NLQ: \"{question}\"\nSQL: """
    conversation.append({"role": "user", "content": user_question_wrapper(sample['question'])})
    sample_dict['input'] = conversation
    input_data.append(sample_dict)
print(input_data[0])
# Out:
# {'id': '282f008dd8dfb8f4a1dd6999', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "Tell me the name of the organism that was detected in the last urine test of patient 10027602 on their first hospital visit?"\nSQL: '}]}

# %%
# First message

print(conversation[0]['content'])
# Out:
# You are 'SQLgpt', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single ' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.

# %%
print(input_data)
# Out:
# [{'id': '282f008dd8dfb8f4a1dd6999', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "Tell me the name of the organism that was detected in the last urine test of patient 10027602 on their first hospital visit?"\nSQL: '}]}, {'id': '47fd000ef0b1033a8aabfac8', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "Show me the top five most frequently prescribed medications since 2100."\nSQL: '}]}, {'id': '7f07c59357750ac2b84e5221', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "What are the five frequently taken specimens for patients that received extirpation of matter from lung lingula, via natural or artificial opening endoscopic previously within 2 months?"\nSQL: '}]}, {'id': 'c83990de3e5d2d218c83528a', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "When does patient 8016\'s influenza quarantine end?"\nSQL: '}]}, {'id': 'f430a02bd152c617a86cd2c3', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "How much is patient 10038933 needed to pay for the cost of their hospital visit in 2100?"\nSQL: '}]}, {'id': '34e18d3b9b2f055f37a2d04d', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "Call a medical supply company to order more icu equipment."\nSQL: '}]}, {'id': 'dfc058cc8e8d30a29c0177b9', 'input': [{'role': 'system', 'content': 'You are \'SQLgpt\', an AI designed to convert natural language questions into their corresponding SQL queries.Importantly, the generated SQL queries should adhere to the standard SQL format and not be enclosed in quotes (neither single \' nor double "). Your primary goal is to accurately generate the exact SQL query for each question presented to you.\n\n'}, {'role': 'user', 'content': '\n\nNLQ: "After  ...

# %%
data[0]
# Out:
# {'id': '282f008dd8dfb8f4a1dd6999',
#  'question': 'Tell me the name of the organism that was detected in the last urine test of patient 10027602 on their first hospital visit?'}

# %%
# Generate answer(SQL) from chatGPT
"""T5 result"""
label_y = myModel.generate(input_data,data)

"""T5 results ensemble."""
#label_y = myModel.generate(input_data,label_T5)
#label_y = myModel.generate(input_data,final_result)
# Out:
# Processing: 100%|██████████| 1167/1167 [44:48<00:00,  2.30s/query]
# 'T5 results ensemble.'

# %%
label_y['d084d1f3c277e6827087bb44'][1][4]
# Out:
# ChatCompletionTokenLogprob(token='0', bytes=[48], logprob=0.0, top_logprobs=[TopLogprob(token='0', bytes=[48], logprob=0.0), TopLogprob(token='1', bytes=[49], logprob=-21.326208), TopLogprob(token='00', bytes=[48, 48], logprob=-26.679605), TopLogprob(token='5', bytes=[53], logprob=-27.61255), TopLogprob(token='10', bytes=[49, 48], logprob=-28.367544)])

# %% [markdown]
# Below is how the predicted labels(SQLs) look like

# %%
import pickle

with open('log_probability_test_new.pickle', 'wb') as f:
    pickle.dump(label_y, f, pickle.HIGHEST_PROTOCOL)

# %%
def top_prob(prob):
    if 'top_logprobs' in prob:
        prob['top_logprobs'] = [dict(x) for x in prob['top_logprobs']]

    return prob

final_data={}
for key in label_y:
    token_prob = [top_prob(dict(x)) for x in label_y[key][1]]
    final_data[key] = [label_y[key][0], token_prob]

# %%
import json
output_filename = 'log_probability_final.json'
# JSON 파일로 저장
with open(output_filename, 'w') as outfile:
    json.dump(final_data, outfile)

print(f"File saved: {output_filename}")
# Out:
# File saved: log_probability_final.json
